# %%
import pandas as pd
import sklearn.model_selection as ms
import sklearn.linear_model as lm
from google.colab import drive

# %%
drive.mount('/content/drive')
# !ls /content/drive/MyDrive/Colab\ Notebooks

# Imporando dataset
vendas = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Aula CSV/Car_sales.csv')
vendas.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# ...

# %%
# Casos que tenham Nan, limpa o daaset
vendas_limpo = vendas.dropna()
vendas_limpo

# %%
# Pegando variavel X = capacidade do motor
# Variavel = dataset.iloc[linha, coluna]
x = vendas_limpo.iloc[:, 6]
x

# %%
# Pegadno variavel Y = Modelo do caro
y = vendas_limpo.iloc[:, 1]
y
